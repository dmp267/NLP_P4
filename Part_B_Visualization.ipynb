# %%
from matplotlib import pyplot as plt

# %%
loss = [0.6923783421516418, 0.607536792755127, 0.7068135738372803, 0.16925862431526184, 1.4157640933990479, 0.9996486902236938, 1.5183366537094116, 1.3447151184082031, 1.2496142387390137, 0.5448552966117859, 1.2564889192581177, 1.0089921951293945, 0.7597265243530273, 1.5692774057388306, 0.45010343194007874, 0.551361083984375, 0.4544989764690399, 0.5357789993286133, 0.33714672923088074, 0.7996827960014343, 1.4119946956634521]
dev_acc = [69.79, 73.53, 75.94, 75.94, 75.13, 75.94, 76.74, 74.87, 75.94, 74.33, 75.94, 78.07, 77.27, 77.01, 78.34, 77.81, 78.61, 78.34, 78.61, 77.81, 78.07]

# %%
time = [400 * x for x in list(range(0, len(loss)))]

# %%
plt.plot(time, dev_acc)
plt.title('Iterations vs. Development Accuracy')
plt.xlabel('Iterations')
plt.ylabel('Accuracy (%)')
plt.show()

# %%
plt.plot(time, loss)
plt.title('Iterations vs. Training Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.show()
